# %% [markdown]
# <a href="https://colab.research.google.com/github/reb-scho/subsidies/blob/main/write_up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd

# !wget https://raw.githubusercontent.com/reb-scho/subsidies/main/my_code.py

from my_code import (
    load_and_clean,
    plot_fig1, plot_fig2, plot_fig3, plot_fig4,
    plot_fig5, plot_fig6, plot_fig7, plot_fig8,
    plot_fig9, plot_fig12, plot_fig13, plot_fig14
)

file_path = '/content/drive/My Drive/colab/subsidies/data/subsidies_raw.xlsx'

(global_product_df, global_total_df, country_product_df, country_total_df,
 country_elec_df, country_fossil_df, country_fossil_agg_df, global_elec_df,
 global_fossil_df, global_fossil_agg_df) = load_and_clean(file_path)

value_label = "Value (Real 2023 USD, billions)"

plot_fig1(global_elec_df, global_fossil_agg_df, value_label)
plot_fig2(global_elec_df, global_fossil_agg_df, value_label)
plot_fig3(global_elec_df, global_fossil_df, value_label)
plot_fig4(global_product_df, value_label)
plot_fig5(global_fossil_agg_df, global_elec_df, value_label)
plot_fig6(global_fossil_df, value_label)
plot_fig8(global_product_df, value_label)
plot_fig12(global_product_df, value_label)
plot_fig13(country_product_df, value_label)
plot_fig14(country_elec_df, country_fossil_df, country_total_df, value_label)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3408444161.py in <cell line: 0>()
#       5
#       6 # Import all functions from code.py
# ----> 7 from my_code import (
#       8     load_and_clean,
#       9     plot_fig1, plot_fig2, plot_fig3, plot_fig4,
#
# ModuleNotFoundError: No module named 'my_code'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
